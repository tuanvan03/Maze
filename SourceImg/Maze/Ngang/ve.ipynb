# %%
import pandas as pd
import matplotlib.pyplot as plt

# Đọc dữ liệu từ file Excel
df = pd.read_excel("D:\\DaiHoc\\HK6\\TKDGTT\\Project\\Maze\\SourceImg\\Maze\\Ngang\\tonghop.xlsx")
# Lọc dữ liệu cho từng thuật toán
bfs_data = df[df['Algorithm'] == 'BFS']
dfs_data = df[df['Algorithm'] == 'DFS']
astar_data = df[df['Algorithm'] == 'AStar']
dijkstra_data = df[df['Algorithm'] == 'Dijkstra']
bidirectional_data = df[df['Algorithm'] == 'Bidirectional']

# Vẽ biểu đồ đường
plt.figure(figsize=(10, 6))

# Vẽ đường cho BFS
plt.plot(bfs_data['Maze'], bfs_data['Runtime (s)'], label='BFS')

# Vẽ đường cho DFS
plt.plot(dfs_data['Maze'], dfs_data['Runtime (s)'], label='DFS')

# Vẽ đường cho AStar
plt.plot(astar_data['Maze'], astar_data['Runtime (s)'], label='AStar')

# Vẽ đường cho Dijkstra
plt.plot(dijkstra_data['Maze'], dijkstra_data['Runtime (s)'], label='Dijkstra')

# Vẽ đường cho Bidirectional
plt.plot(bidirectional_data['Maze'], bidirectional_data['Runtime (s)'], label='Bidirectional')

# Đặt tên trục x
plt.xlabel('Horizontal Maze')

# Đặt tên trục y
plt.ylabel('Runtime (s)')

# Đặt tiêu đề cho biểu đồ
plt.title('Comparison of Algorithm Runtimes')

# Đặt chú thích cho biểu đồ
plt.legend()

# plt.xticks(ticks=range(0),rotation=45)


plt.show()

# %%
# Vẽ biểu đồ đường
plt.figure(figsize=(10, 6))

# Vẽ đường cho BFS
plt.plot(bfs_data['Maze'], bfs_data['Memory Usage (MB)'], label='BFS')

# Vẽ đường cho DFS
plt.plot(dfs_data['Maze'], dfs_data['Memory Usage (MB)'], label='DFS')

# Vẽ đường cho AStar
plt.plot(astar_data['Maze'], astar_data['Memory Usage (MB)'], label='AStar')

# Vẽ đường cho Dijkstra
plt.plot(dijkstra_data['Maze'], dijkstra_data['Memory Usage (MB)'], label='Dijkstra')

# Vẽ đường cho Bidirectional
plt.plot(bidirectional_data['Maze'], bidirectional_data['Memory Usage (MB)'], label='Bidirectional')

# Đặt tên trục x
plt.xlabel('Horizontal Maze')

# Đặt tên trục y
plt.ylabel('Memory Usage (MB)')

# Đặt tiêu đề cho biểu đồ
plt.title('Comparison of Algorithm Memory Usage ')

# Đặt chú thích cho biểu đồ
plt.legend()

# plt.xticks(ticks=range(0),rotation=45)


plt.show()

# %%
# Vẽ biểu đồ đường
plt.figure(figsize=(10, 6))

# Vẽ đường cho BFS
plt.plot(bfs_data['Maze'], bfs_data['Movements'], label='BFS')

# Vẽ đường cho DFS
plt.plot(dfs_data['Maze'], dfs_data['Movements'], label='DFS')

# # Vẽ đường cho AStar
plt.plot(astar_data['Maze'], astar_data['Movements'], label='AStar')

# # Vẽ đường cho Dijkstra
plt.plot(dijkstra_data['Maze'], dijkstra_data['Movements'], label='Dijkstra')

# # Vẽ đường cho Bidirectional
plt.plot(bidirectional_data['Maze'], bidirectional_data['Movements'], label='Bidirectional')

# Đặt tên trục x
plt.xlabel('Horizontal Maze')

# Đặt tên trục y
plt.ylabel('Movements')

# Đặt tiêu đề cho biểu đồ
plt.title('Comparison of Algorithm Movements')

# Đặt chú thích cho biểu đồ
plt.legend()

# plt.xticks(ticks=range(0),rotation=45)


plt.show()
